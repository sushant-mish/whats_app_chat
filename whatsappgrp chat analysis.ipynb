# %%
import re
import emoji
import regex
import pandas as pd
date_string = '26/01/2020'
date_format = '%d/%m/%Y'
date = pd.to_datetime(date_string, format=date_format)
import numpy as np
import plotly.express as px
from collections import Counter
import matplotlib.pyplot as plt
from os import path
from PIL import Image
import datetime
import warnings
warnings.filterwarnings("ignore")
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline

# %%
def startsWithDateAndTimeAndroid(s):
    pattern='^([0-9]+)(\/)([0-9]+)(\/)([0-9]+), ([0-9]+):([0-9]+)[ ]? (AM|PM|am|pm)? -'
    result = re.match(pattern,s)
    if result:
        return True
    return False
    
def FindAuthor(s):
    s=s.split(":")
    if len(s)==2:
        return True
    else:
        return False
def getDataPointAndroid(line):
    splitline=line.split(' - ')
    dateTime=splitline[0]
    date,time=dateTime.split(', ')
    message = ' '.join(splitline[1:])
    if FindAuthor(message):
        splitMessage=message.split(':')
        author = splitMessage[0]
        message = ' '.join(splitMessage[1:])
    else:
        author = None
    return date, time, author, message
def getDataPointios(line):
    splitline=line.split(' - ')
    dateTime=splitline[0]
    date,time=dateTime.split(', ')
    message = ' '.join(splitline[1:])
    if FindAuthor(message):
        splitMessage=message.split(':')
        author = splitMessage[0]
        messgae = ' '.join(splitMessage[1:])
    else:
        author = None
    if time[5]==":":
        time=time[:6]+time[-3:]
    else:
        if 'AM' in time or 'PM' in time:
            time=time[:6]+time[-3:]
        else:
            time=time[:6]
    return date, time, author, message
def split_count(text):
    emoji_list=[]
    emojis_iter=map(lambda y:y, emoki.UNICORN_EMOJI['en'].keys())
    regex_set=re.compile('|'.join(re.escape(em) for em in emojis_iter))
    emoji_list=regex_set.findall(text)
    return emoji_list
parsedData=[]
conversationPath='\\Users\\KIIT\\Desktop\\kuch_kaam.txt'
with open(conversationPath,encoding="utf-8")as fp:
    device = ' '
    first = fp.readline()
    print(first)
    if '[' in first:
        device='ios'
    else:
        device="android"
    fp.readline()
    messageBuffer=[]
    date,time,author=None,None,None
    while True:
        line=fp.readline()
        if not line:
            break
        if device=="ios":
            line=line.strip()
            if startsWithDateAndTimeAndroid(line):
                if len(messageBuffer)>0:
                    parsedData.append([date,time,author, ' '.join(messageBuffer)])
                messageBuffer.clear()
                date, time, author, message=getDataPointios(line)
                messageBuffer.append(message)
            else:
                line=(line.encode('ascii','ignore')).decode("utf-8")
                if startsWithDateAndTimeAndroid(line):
                    if len(messageBuffer)>0:
                        parsedData.append([date,time,author, ' '.join(messageBuffer)])
                    messageBuffer.clear()
                    date, time, author, message=getDataPointios(line)
                    messageBuffer.append(message)
                else:
                    messageBuffer.append(line)
        else:
            line=line.strip()
            if startsWithDateAndTimeAndroid(line):
                if len(messageBuffer)>0:
                    parsedData.append([date,time,author,' '.join(messageBuffer)])
                messageBuffer.clear()
                date, time, author, message=getDataPointios(line)
                messageBuffer.append(message)
            else:
                messageBuffer.append(line)
def dateconv(date_str):
    return datetime.datetime.strptime(date_str, '%d/%m/%Y').strftime('%Y-%m-%d')
if device =='android':
    df=pd.DataFrame(parsedData,columns=['Date','Time','Author','Message'])
    df["Date"]=pd.to_datetime(df["Date"])
    df=df.dropna()
    URLPATTERN=r'(https?://\S+)'
    df['urlcount']=df.Message.apply(lambda x: re.findall(URLPATTERN,x)).str.len()
else:
    df=pd.DataFrame(parsedData,columns=['Date','Time','Author','Message'])
    df=df.dropna()
    df['Date'] = df['Date'].apply(dateconv)
    df['Date'] = pd.to_datetime(df["Date"], format='%Y-%m-%d')
    URLPATTERN=r'(https?://\S+)'
    df['urlcount']=df.Message.apply(lambda x: re.findall(URLPATTERN,x)).str.len()
# Out:
# 26/01/2020, 4:19 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.

# %%
df.head(10)
# Out:
#           Date    Time                      Author  \
# 111 2020-01-27  7:31 p             +91 96536 93868
# 112 2020-01-27  7:31 p             +91 96536 93868
# 113 2020-01-27  7:31 p  Dheeraj Lalwani (TSEC, CS)
# 114 2020-01-27  7:32 p  Dheeraj Lalwani (TSEC, CS)
# 115 2020-01-27  7:32 p             +91 96536 93868
# 116 2020-01-27  7:32 p  Dheeraj Lalwani (TSEC, CS)
# 117 2020-01-27  7:43 p             +91 99201 75875
# 118 2020-01-27  7:43 p  Dheeraj Lalwani (TSEC, CS)
# 119 2020-01-27  7:44 p  Dheeraj Lalwani (TSEC, CS)
# 120 2020-01-27  7:59 p             +91 95949 08570
#
#                                                Message  urlcount
# 111                   +91 96536 93868: <Media omitted>         0
# 112                +91 96536 93868: Give it a try ....         0
# 113                Dheeraj Lalwani (TSEC, CS): Alright         0
# 114  Dheeraj Lalwani (TSEC, CS): We can make this a...         0
# 115                              +91 96536 93868: Sure         0
# 116  Dheeraj Lalwani (TSEC, CS): Everyday a new cha...         0
# 117   +91 99201 75875: More of logic or algo problems^         0
# 118                   Dheeraj Lalwani (TSEC, CS): Yeah         0
# 119  Dheeraj Lalwani (TSEC, CS): Something or the o...         0
# 120                       +91 95949 08570: Nice idea 🤟         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3512 entries, 111 to 3979
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3512 non-null   datetime64[ns]
#  1   Time      3512 non-null   object
#  2   Author    3512 non-null   object
#  3   Message   3512 non-null   object
#  4   urlcount  3512 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 164.6+ KB

# %%
df.Author.unique()
# Out:
# array(['+91 96536 93868', 'Dheeraj Lalwani (TSEC, CS)', '+91 99201 75875',
#        '+91 95949 08570', '+91 79778 76844', '+91 90499 38860',
#        'Tanay Kamath (TSEC, CS)', 'Saket (TSEC, CS)', '+91 77568 95072',
#        'Rohit Pathak (TSEC, CS)', '+91 75078 05454',
#        'Darshan Rander (TSEC, IT)', '+91 79774 68083', '+91 70394 60876',
#        '+91 96191 55044', '+91 90678 93300', 'Mohit Varma (TSEC, CS)',
#        '+91 79770 56210', 'Chirag Sharma (TSEC, CS)',
#        'Vivek Iyer (TSEC, Biomed)', 'Tushar Nankani', '+91 81696 22410',
#        '+91 89764 07509', '+91 78758 66747', 'Ankit (TSEC, CS)',
#        '+91 86556 33169', '+91 76663 28147', '+91 88284 70904',
#        '+91 97698 67348', 'Vivek (TSEC, CS)', 'Hardik Raheja (TSEC, CS)',
#        '+91 91680 38866', 'Mittul Dasani (TSEC, CS)',
#        'Kartik Soneji (TSEC, CS)', '+91 77180 43697', '+91 99676 84479',
#        'Shreya (TSEC, IT)', '+91 96190 16721', '+91 89833 85127',
#        '+91 99675 58551', '+91 90822 59476', 'Prithvi Rohira (TSEC, CS)',
#        '+91 90820 98830', 'Mohammed (TSEC, EXTC)', '+91 96992 89993',
#        '+91 83690 21693', '+91 75064 86714', 'Pratik K (TSEC CS, SE)',
#        'Farhan Irani (TSEC IT, SE)', '+91 77000 27264',
#        'Harsh Kapadia (TSEC IT, SE)', 'Saurav Upoor (TSEC CS, SE)',
#        '+91 77180 82108', '+91 86559 19035', '+91 77150 51136',
#        '+91 91671 28174', '+91 84335 18102', '+91 84529 62233',
#        '+91 81080 96759', '+91 82080 02653', '+91 93243 92133',
#        '+91 97681 67131', '+91 98206 01141', '+91 84540 03063',
#        '+91 99693 94098', '+91 88305 26885', '+91 70208 31915',
#        '+91 97027 35002', '+91 98192 22032', '+91 97739 65140',
#        '+91 97571 15289', 'Rishab Saini (TSEC CS, TE)', '+91 94208 78848',
#        '+91 93598 18687', '+91 73043 57388', '+91 98331 51331',
#        '+91 80979 84068', '+91 99697 55118', '+91 95119 48511',
#        '+91 82916 21138', '+91 98337 61116', '+91 88889 97733',
#        '+91 97697 60869', '+91 99672 39663', '+91 87796 70896',
#        '+91 98191 73361'], dtype=object)

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3512 entries, 111 to 3979
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3512 non-null   datetime64[ns]
#  1   Time      3512 non-null   object
#  2   Author    3512 non-null   object
#  3   Message   3512 non-null   object
#  4   urlcount  3512 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 164.6+ KB

# %%
total_message = df.shape[0]
print(total_message)
# Out:
# 3512

# %%
media_messages = df[df['Message']=='<Media omitted>'].shape[0]
print(media_messages)
# Out:
# 0

# %%
URLPATTERN = r'(https?://\S+)'
df['urlcount'] = df.Message.apply(lambda x: re.findall(URLPATTERN, x)).str.len()
links = sum(df.urlcount)
print(links)
# Out:
# 37

# %%
link_messages = df[df['urlcount']>0]
deleted_messages = df[(df["Message"] == "You deleted this message")| (df["Message"] == " This message was deleted. ")]
media_messages_df = df[(df['Message'] == '<Media omitted>') | (df['Message'] == 'images omitted') | (df['Message'] == ' video omitted ') | (df['Message'] == ' sticker omitted ')]
messages_df = df.drop(media_messages_df.index)
messages_df = messages_df.drop(deleted_messages.index)
messages_df = messages_df.drop(link_messages.index)

# %%
messages_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3485 entries, 111 to 3979
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3485 non-null   datetime64[ns]
#  1   Time      3485 non-null   object
#  2   Author    3485 non-null   object
#  3   Message   3485 non-null   object
#  4   urlcount  3485 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 163.4+ KB

# %%
messages_df['Letter_Count'] = messages_df['Message'].apply(lambda s : len(s))
messages_df['word_count']= messages_df['Message'].apply(lambda s: len(s.split(' ')))
messages_df['MessageCount'] = 1

# %%
messages_df.head(10)
# Out:
#           Date    Time                      Author  \
# 111 2020-01-27  7:31 p             +91 96536 93868
# 112 2020-01-27  7:31 p             +91 96536 93868
# 113 2020-01-27  7:31 p  Dheeraj Lalwani (TSEC, CS)
# 114 2020-01-27  7:32 p  Dheeraj Lalwani (TSEC, CS)
# 115 2020-01-27  7:32 p             +91 96536 93868
# 116 2020-01-27  7:32 p  Dheeraj Lalwani (TSEC, CS)
# 117 2020-01-27  7:43 p             +91 99201 75875
# 118 2020-01-27  7:43 p  Dheeraj Lalwani (TSEC, CS)
# 119 2020-01-27  7:44 p  Dheeraj Lalwani (TSEC, CS)
# 120 2020-01-27  7:59 p             +91 95949 08570
#
#                                                Message  urlcount  \
# 111                   +91 96536 93868: <Media omitted>         0
# 112                +91 96536 93868: Give it a try ....         0
# 113                Dheeraj Lalwani (TSEC, CS): Alright         0
# 114  Dheeraj Lalwani (TSEC, CS): We can make this a...         0
# 115                              +91 96536 93868: Sure         0
# 116  Dheeraj Lalwani (TSEC, CS): Everyday a new cha...         0
# 117   +91 99201 75875: More of logic or algo problems^         0
# 118                   Dheeraj Lalwani (TSEC, CS): Yeah         0
# 119  Dheeraj Lalwani (TSEC, CS): Something or the o...         0
# 120                       +91 95949 08570: Nice idea 🤟         0
#
#      Letter_Count  word_count  MessageCount
# 111            32           5             1
# 112            35           8             1
# 113            35           5             1
# 114            52          10             1
# 115            21           4             1
# 116            52           8             1
# 117            48           9             1
# 118            32           5             1
# 119            98          17             1
# 120            28           6             1

# %%
frnds = messages_df.Author.unique()
for i in range(len(frnds)):
    # filtering out mesaages of particular user
    req_df = messages_df[messages_df["Author"] == frnds[i]]
    # req_df will contain messages of only one particular user
    print(f'Stats of {frnds[i]} -')
    # shape will print number of rows which indirectly means the number of messages
    print('Messages Sent', req_df.shape[0])
    # Word_count contains of total words in one message . Sum of all words/ Total Message wil yield words
    words_per_message = (np.sum(req_df['word_count']))/req_df.shape[0]
    print('Words per message', words_per_message)
    #media consists of media messages
    media = media_messages_df[media_messages_df['Author'] == frnds[i]].shape[0]
    print('Media messages Sent' , media)
    
    #links consists of total links
    links = sum(link_messages[link_messages['Author'] == frnds[i]]["urlcount"])
    print('Links Sent', links)
    print()
# Out:
# Stats of +91 96536 93868 -
# Messages Sent 65
# Words per message 18.73846153846154
# Media messages Sent 0
# Links Sent 0
#
# Stats of Dheeraj Lalwani (TSEC, CS) -
# Messages Sent 518
# Words per message 9.432432432432432
# Media messages Sent 0
# Links Sent 6
#
# Stats of +91 99201 75875 -
# Messages Sent 26
# Words per message 15.423076923076923
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 95949 08570 -
# Messages Sent 96
# Words per message 6.895833333333333
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 79778 76844 -
# Messages Sent 2
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 90499 38860 -
# Messages Sent 2
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Tanay Kamath (TSEC, CS) -
# Messages Sent 688
# Words per message 8.611918604651162
# Media messages Sent 0
# Links Sent 2
#
# Stats of Saket (TSEC, CS) -
# Messages Sent 76
# Words per message 11.407894736842104
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 77568 95072 -
# Messages Sent 1
# Words per message 25.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Rohit Pathak (TSEC, CS) -
# Messages Sent 17
# Words per message 7.294117647058823
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 75078 05454 -
# Messages Sent 32
# Words per message 9.03125
# Media messages Sent 0
# Links Sent 0
#
# Stats of Darshan Rander (TSEC, IT) -
# Messages Sent 388
# Words per message 9.22938144329897
# Media messages Sent 0
# Links Sent 1
#
# Stats of +91 79774 68083 -
# Messages Sent 8
# Words per message 6.625
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 70394 60876 -
# Messages Sent 29
# Words per message 13.96551724137931
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 96191 55044 -
# Messages Sent 9
# Words per message 7.111111111111111
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 90678 93300 -
# Messages Sent 1
# Words per message 5.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Mohit Varma (TSEC, CS) -
# Messages Sent 20
# Words per message 9.4
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 79770 56210 -
# Messages Sent 72
# Words per message 12.61111111111111
# Media messages Sent 0
# Links Sent 0
#
# Stats of Chirag Sharma (TSEC, CS) -
# Messages Sent 44
# Words per message 9.613636363636363
# Media messages Sent 0
# Links Sent 0
#
# Stats of Vivek Iyer (TSEC, Biomed) -
# Messages Sent 53
# Words per message 7.566037735849057
# Media messages Sent 0
# Links Sent 0
#
# Stats of Tushar Nankani -
# Messages Sent 65
# Words per message 15.123076923076923
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 81696 22410 -
# Messages Sent 3
# Words per message 6.666666666666667
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 89764 07509 -
# Messages Sent 91
# Words per message 12.989010989010989
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 78758 66747 -
# Messages Sent 7
# Words per message 9.428571428571429
# Media messages Sent 0
# Links Sent 0
#
# Stats of Ankit (TSEC, CS) -
# Messages Sent 32
# Words per message 9.3125
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 86556 33169 -
# Messages Sent 3
# Words per message 8.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 76663 28147 -
# Messages Sent 1
# Words per message 7.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 88284 70904 -
# Messages Sent 41
# Words per message 6.975609756097561
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 97698 67348 -
# Messages Sent 1
# Words per message 5.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Vivek (TSEC, CS) -
# Messages Sent 8
# Words per message 9.375
# Media messages Sent 0
# Links Sent 0
#
# Stats of Hardik Raheja (TSEC, CS) -
# Messages Sent 3
# Words per message 11.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 91680 38866 -
# Messages Sent 1
# Words per message 7.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Mittul Dasani (TSEC, CS) -
# Messages Sent 13
# Words per message 7.153846153846154
# Media messages Sent 0
# Links Sent 1
#
# Stats of Kartik Soneji (TSEC, CS) -
# Messages Sent 52
# Words per message 14.903846153846153
# Media messages Sent 0
# Links Sent 3
#
# Stats of +91 77180 43697 -
# Messages Sent 1
# Words per message 8.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 99676 84479 -
# Messages Sent 2
# Words per message 7.5
# Media messages Sent 0
# Links Sent 0
#
# Stats of Shreya (TSEC, IT) -
# Messages Sent 9
# Words per message 7.666666666666667
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 96190 16721 -
# Messages Sent 1
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 89833 85127 -
# Messages Sent 1
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 99675 58551 -
# Messages Sent 8
# Words per message 6.5
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 90822 59476 -
# Messages Sent 3
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Prithvi Rohira (TSEC, CS) -
# Messages Sent 4
# Words per message 10.25
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 90820 98830 -
# Messages Sent 9
# Words per message 13.555555555555555
# Media messages Sent 0
# Links Sent 0
#
# Stats of Mohammed (TSEC, EXTC) -
# Messages Sent 13
# Words per message 10.615384615384615
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 96992 89993 -
# Messages Sent 3
# Words per message 6.666666666666667
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 83690 21693 -
# Messages Sent 5
# Words per message 8.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 75064 86714 -
# Messages Sent 1
# Words per message 7.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Pratik K (TSEC CS, SE) -
# Messages Sent 313
# Words per message 9.910543130990416
# Media messages Sent 0
# Links Sent 10
#
# Stats of Farhan Irani (TSEC IT, SE) -
# Messages Sent 108
# Words per message 9.953703703703704
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 77000 27264 -
# Messages Sent 7
# Words per message 9.857142857142858
# Media messages Sent 0
# Links Sent 0
#
# Stats of Harsh Kapadia (TSEC IT, SE) -
# Messages Sent 79
# Words per message 11.08860759493671
# Media messages Sent 0
# Links Sent 3
#
# Stats of Saurav Upoor (TSEC CS, SE) -
# Messages Sent 243
# Words per message 10.74074074074074
# Media messages Sent 0
# Links Sent 4
#
# Stats of +91 77180 82108 -
# Messages Sent 16
# Words per message 11.5625
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 86559 19035 -
# Messages Sent 6
# Words per message 6.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 77150 51136 -
# Messages Sent 6
# Words per message 4.666666666666667
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 91671 28174 -
# Messages Sent 1
# Words per message 5.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 84335 18102 -
# Messages Sent 17
# Words per message 7.529411764705882
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 84529 62233 -
# Messages Sent 11
# Words per message 5.818181818181818
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 81080 96759 -
# Messages Sent 4
# Words per message 6.25
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 82080 02653 -
# Messages Sent 3
# Words per message 7.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 93243 92133 -
# Messages Sent 13
# Words per message 5.615384615384615
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 97681 67131 -
# Messages Sent 4
# Words per message 8.5
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 98206 01141 -
# Messages Sent 29
# Words per message 7.931034482758621
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 84540 03063 -
# Messages Sent 3
# Words per message 5.666666666666667
# Media messages Sent 0
# Links Sent 2
#
# Stats of +91 99693 94098 -
# Messages Sent 14
# Words per message 18.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 88305 26885 -
# Messages Sent 5
# Words per message 12.2
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 70208 31915 -
# Messages Sent 1
# Words per message 6.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 97027 35002 -
# Messages Sent 17
# Words per message 6.0588235294117645
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 98192 22032 -
# Messages Sent 1
# Words per message 14.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 97739 65140 -
# Messages Sent 5
# Words per message 21.4
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 97571 15289 -
# Messages Sent 4
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of Rishab Saini (TSEC CS, TE) -
# Messages Sent 7
# Words per message 10.285714285714286
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 94208 78848 -
# Messages Sent 2
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 73043 57388 -
# Messages Sent 15
# Words per message 27.066666666666666
# Media messages Sent 0
# Links Sent 3
#
# Stats of +91 98331 51331 -
# Messages Sent 1
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 80979 84068 -
# Messages Sent 2
# Words per message 6.5
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 99697 55118 -
# Messages Sent 3
# Words per message 5.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 95119 48511 -
# Messages Sent 1
# Words per message 6.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 82916 21138 -
# Messages Sent 7
# Words per message 9.714285714285714
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 98337 61116 -
# Messages Sent 1
# Words per message 9.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 88889 97733 -
# Messages Sent 1
# Words per message 5.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 97697 60869 -
# Messages Sent 1
# Words per message 9.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 99672 39663 -
# Messages Sent 1
# Words per message 4.0
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 87796 70896 -
# Messages Sent 2
# Words per message 4.5
# Media messages Sent 0
# Links Sent 0
#
# Stats of +91 98191 73361 -
# Messages Sent 3
# Words per message 4.666666666666667
# Media messages Sent 0
# Links Sent 0

# %%
messages_df['Time'].value_counts().head(10).plot.barh()
plt.xlabel('Time')
plt.ylabel('number of messages')
# Out:
# Text(0, 0.5, 'number of messages')

# %%
text = " ".join(review for review in messages_df['Message'])
print("There are {} words in all the messages.".format(len(text)))
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, background_color = 'white'). generate(text)

plt.figure(figsize = (10, 5))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()
# Out:
# There are 198149 words in all the messages.

# %%
l = [ ]
for i in range(len(l)):
    dummy_df = messages_df[messages_df['Author'] == l[i]]
    text = " ".john(review for review in dummy_df.Message)
    stopwords = set(STOPWORDS)
    #generate a  word cloud image
    print('Author name', l[i])
    wordcloud = wordCloud(stopwords, background_color = "white").generate(text)
    #Display the generated image
    plt.figure(figsize = (10, 5))
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.show()
